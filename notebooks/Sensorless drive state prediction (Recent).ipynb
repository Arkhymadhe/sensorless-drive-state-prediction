# %%
# Importing required libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

# %%
# Loading in the data
DIR = os.getcwd().replace('notebooks', 'data')
data = np.loadtxt(DIR + '\\' + 'dataset' + '\\' + 'Sensorless_drive_diagnosis.txt')

# %%
data.shape
# Out:
# (58509, 49)

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#              0             1         2         3             4         5   \
# 0 -3.014600e-07  8.260300e-06 -0.000012 -0.000002 -1.438600e-06 -0.000021
# 1  2.913200e-06 -5.247700e-06  0.000003 -0.000006  2.778900e-06 -0.000004
# 2 -2.951700e-06 -3.184000e-06 -0.000016 -0.000001 -1.575300e-06  0.000017
# 3 -1.322600e-06  8.820100e-06 -0.000016 -0.000005 -7.282900e-07  0.000004
# 4 -6.836600e-08  5.666300e-07 -0.000026 -0.000006 -7.940600e-07  0.000013
#
#          6         7         8         9   ...       39      40      41  \
# 0  0.031718  0.031710  0.031721 -0.032963  ... -0.63308  2.9646  8.1198
# 1  0.030804  0.030810  0.030806 -0.033520  ... -0.59314  7.6252  6.1690
# 2  0.032877  0.032880  0.032896 -0.029834  ... -0.63252  2.7784  5.3017
# 3  0.029410  0.029401  0.029417 -0.030156  ... -0.62289  6.5534  6.2606
# 4  0.030119  0.030119  0.030145 -0.031393  ... -0.63010  4.5155  9.5231
#
#        42      43      44      45      46      47   48
# 0 -1.4961 -1.4961 -1.4961 -1.4996 -1.4996 -1.4996  1.0
# 1 -1.4967 -1.4967 -1.4967 -1.5005 -1.5005 -1.5005  1.0
# 2 -1.4983 -1.4983 -1.4982 -1.4985 -1.4985 -1.4985  1.0
# 3 -1.4963 -1.4963 -1.4963 -1.4975 -1.4975 -1.4976  1.0
# 4 -1.4958 -1.4958 -1.4958 -1.4959 -1.4959 -1.4959  1.0
#
# [5 rows x 49 columns]

# %%
desc = {'name' : pd.Series(np.array(data.columns) + 1).apply(lambda x: f'Feature {x}'),
        'null' : data.isnull().sum(),
        'null%' : data.isnull().sum()/data.shape[0],
        'unique' : data.nunique(),
        'unique%' : data.nunique()/data.shape[0],
        'dtypes' : data.dtypes}

desc = pd.DataFrame(desc)

# %%
desc
# Out:
#           name  null  null%  unique   unique%   dtypes
# 0    Feature 1     0    0.0   50500  0.863115  float64
# 1    Feature 2     0    0.0   52709  0.900870  float64
# 2    Feature 3     0    0.0   52501  0.897315  float64
# 3    Feature 4     0    0.0   51298  0.876754  float64
# 4    Feature 5     0    0.0   52523  0.897691  float64
# 5    Feature 6     0    0.0   52423  0.895982  float64
# 6    Feature 7     0    0.0   43677  0.746501  float64
# 7    Feature 8     0    0.0   43582  0.744877  float64
# 8    Feature 9     0    0.0   43665  0.746295  float64
# 9   Feature 10     0    0.0   44196  0.755371  float64
# 10  Feature 11     0    0.0   44313  0.757371  float64
# 11  Feature 12     0    0.0   44422  0.759234  float64
# 12  Feature 13     0    0.0   16551  0.282880  float64
# 13  Feature 14     0    0.0   29770  0.508811  float64
# 14  Feature 15     0    0.0   42721  0.730161  float64
# 15  Feature 16     0    0.0   17611  0.300996  float64
# 16  Feature 17     0    0.0   29740  0.508298  float64
# 17  Feature 18     0    0.0   42657  0.729067  float64
# 18  Feature 19     0    0.0   12812  0.218975  float64
# 19  Feature 20     0    0.0   12798  0.218736  float64
# 20  Feature 21     0    0.0   12738  0.217710  float64
# 21  Feature 22     0    0.0   12754  0.217984  float64
# 22  Feature 23     0    0.0   12738  0.217710  float64
# 23  Feature 24     0    0.0   12691  0.216907  float64
# 24  Feature 25     0    0.0   48937  0.836401  float64
# 25  Feature 26     0    0.0   51871  0.886547  float64
# 26  Feature 27     0    0.0   51524  0.880617  float64
# 27  Feature 28     0    0.0   49711  0.849630  float64
# 28  Feature 29     0    0.0   51754  0.884548  float64
# 29  Feature 30     0    0.0   51602  0.881950  float64
# 30  Feature 31     0    0.0   50113  0.856501  float64
# 31  Feature 32     0    0.0   50085  0.856022  float64
# 32  Feature 33     0    0.0   50037  0.855202  float64
# 33  Feature 34     0    0.0   50709  0.866687  float64
# 34  Feature 35     0    0.0   50910  0.870123  float64
# 35  Feature 36     0    0.0   50888  0.869747  float64
# 36  Feature 37     0    0.0   29145  0.498128  float64
# 37  Feature 38     0    0.0   46556  0.795707  float64
# 38  Feature 39     0    0.0   42536  0.726999  float64
# 39  Feature 40     0    0.0   29454  0.503410  float64
# 40  Feature 41     0    0.0   46788  0.799672  float64
# 41  Feature 42     0    0.0   42377  0.724282  float64
# 42  Feature 43     0    0.0     265  0.004529  float64
# 43  Feature 44     0    0.0     267  0.004563  float64
# 44  Feature 45     0    0.0     264  0.004512  float64
# 45  Feature 46     0    0.0     242  0.004136  float64
# 46  Feature 47     0    0.0     243  0.004153  float64
# 47  Feature 48     0    0.0     243  0.004153  float64
# 48  Feature 49     0    0.0      11  0.000188  float64

# %%
data.describe()
# Out:
#                  0             1             2             3             4   \
# count  58509.000000  5.850900e+04  5.850900e+04  58509.000000  5.850900e+04
# mean      -0.000003  1.439648e-06  1.412013e-06     -0.000001  1.351239e-06
# std        0.000072  5.555429e-05  2.353009e-04      0.000063  5.660943e-05
# min       -0.013721 -5.414400e-03 -1.358000e-02     -0.012787 -8.355900e-03
# 25%       -0.000007 -1.444400e-05 -7.239600e-05     -0.000005 -1.475300e-05
# 50%       -0.000003  8.804600e-07  5.137700e-07     -0.000001  7.540200e-07
# 75%        0.000002  1.877700e-05  7.520000e-05      0.000004  1.906200e-05
# max        0.005784  4.525300e-03  5.237700e-03      0.001453  8.245100e-04
#
#                  5             6             7             8             9   \
# count  5.850900e+04  58509.000000  58509.000000  58509.000000  58509.000000
# mean  -2.654483e-07      0.001915      0.001913      0.001912     -0.011897
# std    2.261907e-04      0.036468      0.036465      0.036470      0.066482
# min   -9.741300e-03     -0.139890     -0.135940     -0.130860     -0.218640
# 25%   -7.379100e-05     -0.019927     -0.019951     -0.019925     -0.032144
# 50%   -1.659300e-07      0.013226      0.013230      0.013247     -0.015566
# 75%    7.138600e-05      0.024770      0.024776      0.024777      0.020614
# max    2.753600e-03      0.069125      0.069130      0.069131      0.352580
#
#        ...            39            40            41            42  \
# count  ...  58509.000000  58509.000000  58509.000000  58509.000000
# mean   ...     -0.397757      7.293781      8.273772     -1.500887
# std    ...     25.018728     12.451781      6.565952      0.003657
# min    ...     -0.902350     -0.596830      0.320660     -1.525500
# 25%    ...     -0.715470      1.450300      4.436300     -1.503300
# 50%    ...     -0.661710      3.301300      6.479100     -1.500300
# 75%    ...     -0.573980      8.288500      9.857500     -1.498200
# max    ...   3670.800000    889.930000    153.150000     -1.457600
#
#                  43            44            45            46            47  \
# count  58509.000000  58509.000000  58509.000000  58509.000000  58509.000000
# mean      -1.500912     -1.500805     -1.497771     -1.497794     -1.497686
# std        0.003668      0.003632      0.003163      0.003163      0.003175
# min       -1.526200     -1.523700     -1.521400     -1.523200     -1.521300
# 25%       -1.503400     -1.503200     -1.499600     -1.499600     -1.499500
# 50%       -1.500300     -1.500300     -1.498100     -1.498100     -1.498000
# 75%       -1.498200     -1.498200     -1.496200     -1.496300     -1.496200
# max       -1.456100     -1.455500     -1.337200     -1.337200     -1.337100
#
#                  48
# count  58509.000000
# mean       6.000000
# std        3.162305
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%        9.000000
# max       11.000000
#
# [8 rows x 49 columns]

# %%
plt.figure(figsize = (10, 8))
sns.countplot(x = 48, data = data)
plt.show()

# %%
# Univariate visualization
def univariate_plot(data):
    
    ''' Plot the data univariately. '''
    
    for col in data.columns:
        plt.figure(figsize = (10, 8))
        sns.distplot(data[col])
        plt.show()

# %%
data.groupby(by = 48)[48].count()
# Out:
# 48
# 1.0     5319
# 2.0     5319
# 3.0     5319
# 4.0     5319
# 5.0     5319
# 6.0     5319
# 7.0     5319
# 8.0     5319
# 9.0     5319
# 10.0    5319
# 11.0    5319
# Name: 48, dtype: int64

# %% [markdown]
# <h4> As can be seen from the analysis made above, the data is balanced with respect to class. This means that the accuracy metric can be trusted.<h4>

# %%
univariate_plot(data)
# Out:
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PROBOOK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# sns.pairplot(data = data, hue = 48)

# %% [markdown]
# <h4> We will be fitting the data to an instance of the ExtraTree classifier.

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
tree = ExtraTreesClassifier(max_depth = 3, random_state = 42)

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.iloc[:, : -1]
y = data.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, stratify = y)

# %%
tree.fit(X_train, y_train)
yhat = tree.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
print(classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.80      0.70      0.74      1329
#          2.0       0.90      0.73      0.81      1330
#          3.0       0.73      0.95      0.83      1330
#          4.0       0.94      0.84      0.89      1329
#          5.0       0.92      0.52      0.66      1330
#          6.0       0.72      0.55      0.62      1330
#          7.0       0.89      1.00      0.94      1330
#          8.0       0.70      0.95      0.80      1330
#          9.0       0.72      0.79      0.75      1330
#         10.0       0.77      0.93      0.85      1330
#         11.0       1.00      1.00      1.00      1330
#
#     accuracy                           0.81     14628
#    macro avg       0.83      0.81      0.81     14628
# weighted avg       0.83      0.81      0.81     14628

# %% [markdown]
# <h4>From the results obtained above, it is seen that the model performs quite well, even without any serious hyperparametric tuning. Let us attempt to improve it through feature selection.

# %%
feature_ranks = tree.feature_importances_

# %%
feature_ranks
# Out:
# array([2.12076348e-04, 3.81774564e-03, 1.00965952e-04, 0.00000000e+00,
#        5.28483714e-03, 2.84078561e-05, 1.27998516e-01, 1.26967969e-01,
#        1.61452560e-01, 1.73879662e-01, 1.54766864e-01, 1.00726662e-01,
#        1.59548529e-03, 1.14847430e-03, 1.17977292e-05, 3.67943824e-03,
#        2.56858326e-03, 1.53250880e-05, 1.85661652e-02, 1.26716387e-02,
#        3.55142933e-03, 1.13457102e-02, 7.62548034e-03, 1.13320893e-02,
#        4.51525224e-06, 1.13404725e-04, 1.49806270e-05, 3.34835126e-05,
#        3.82235017e-04, 0.00000000e+00, 4.62861569e-03, 7.14337776e-03,
#        1.89025762e-02, 3.18602844e-03, 7.62379687e-03, 2.40525841e-02,
#        1.15871210e-05, 1.48473746e-05, 1.80185887e-05, 2.54501294e-05,
#        4.66780683e-06, 3.52293334e-05, 1.60896522e-04, 4.92442172e-04,
#        1.91794621e-03, 5.85411140e-05, 1.44369264e-03, 3.83200566e-04])

# %%
feature_ranks.shape
# Out:
# (48,)

# %%
plt.figure(figsize = (20, 8))
sns.barplot(x = data.iloc[:, : -1].columns, y = 10**3*feature_ranks, color = 'blue')
plt.show(); plt.close('all')

# %%
importances = pd.DataFrame({'Importance' : 1000*feature_ranks,
                            'Feature' : ['Feature {}'.format(i + 1) for i in data.iloc[:, : -1].columns]
                           })

# %%
importances
# Out:
#     Importance     Feature
# 0     0.212076   Feature 1
# 1     3.817746   Feature 2
# 2     0.100966   Feature 3
# 3     0.000000   Feature 4
# 4     5.284837   Feature 5
# 5     0.028408   Feature 6
# 6   127.998516   Feature 7
# 7   126.967969   Feature 8
# 8   161.452560   Feature 9
# 9   173.879662  Feature 10
# 10  154.766864  Feature 11
# 11  100.726662  Feature 12
# 12    1.595485  Feature 13
# 13    1.148474  Feature 14
# 14    0.011798  Feature 15
# 15    3.679438  Feature 16
# 16    2.568583  Feature 17
# 17    0.015325  Feature 18
# 18   18.566165  Feature 19
# 19   12.671639  Feature 20
# 20    3.551429  Feature 21
# 21   11.345710  Feature 22
# 22    7.625480  Feature 23
# 23   11.332089  Feature 24
# 24    0.004515  Feature 25
# 25    0.113405  Feature 26
# 26    0.014981  Feature 27
# 27    0.033484  Feature 28
# 28    0.382235  Feature 29
# 29    0.000000  Feature 30
# 30    4.628616  Feature 31
# 31    7.143378  Feature 32
# 32   18.902576  Feature 33
# 33    3.186028  Feature 34
# 34    7.623797  Feature 35
# 35   24.052584  Feature 36
# 36    0.011587  Feature 37
# 37    0.014847  Feature 38
# 38    0.018019  Feature 39
# 39    0.025450  Feature 40
# 40    0.004668  Feature 41
# 41    0.035229  Feature 42
# 42    0.160897  Feature 43
# 43    0.492442  Feature 44
# 44    1.917946  Feature 45
# 45    0.058541  Feature 46
# 46    1.443693  Feature 47
# 47    0.383201  Feature 48

# %%
# Selecting the indexes of features which have importances greater than 1
i = 0
indexes = []

while i < 48:
    if list(1000*feature_ranks)[i] > 1:
        indexes.append(i)
    i += 1

# %%
indexes
# Out:
# [1,
#  4,
#  6,
#  7,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  15,
#  16,
#  18,
#  19,
#  20,
#  21,
#  22,
#  23,
#  30,
#  31,
#  32,
#  33,
#  34,
#  35,
#  44,
#  46]

# %%
### Index out selected features
X_train_new = X_train.iloc[:, indexes]
X_test_new = X_test.iloc[:, indexes]

# %%
new_tree = ExtraTreesClassifier(max_depth = 3, random_state = 42)

# %%
### Train model and test preformance
new_tree.fit(X_train_new, y_train)
new_yhat = new_tree.predict(X_test_new)

# %%
print(classification_report(y_test, new_yhat))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.71      0.87      0.78      1329
#          2.0       0.84      0.70      0.77      1330
#          3.0       0.80      0.94      0.86      1330
#          4.0       0.98      0.90      0.94      1329
#          5.0       0.85      0.69      0.76      1330
#          6.0       0.67      0.31      0.42      1330
#          7.0       0.97      1.00      0.99      1330
#          8.0       0.81      0.96      0.88      1330
#          9.0       0.73      0.86      0.79      1330
#         10.0       0.75      0.89      0.81      1330
#         11.0       1.00      1.00      1.00      1330
#
#     accuracy                           0.83     14628
#    macro avg       0.83      0.83      0.82     14628
# weighted avg       0.83      0.83      0.82     14628

# %% [markdown]
# <h4> We seem to have cut down on the not-so-important features. The ExtraTreesClassifier has an even more competent degree of accuracy. Perhaps this can be improved on by utilizing it as the basis for a boosting machine.<h4>
#
# The selected boosting machine is an AdaBoostClassifier.

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
Ada_model = AdaBoostClassifier(base_estimator = ExtraTreesClassifier(max_depth = 3, random_state = 42), random_state = 42)

# %%
Ada_model.fit(X_train_new, y_train)
yhat = Ada_model.predict(X_test_new)
print(classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.95      0.97      1329
#          2.0       0.90      0.87      0.89      1330
#          3.0       1.00      1.00      1.00      1330
#          4.0       1.00      0.99      0.99      1329
#          5.0       0.97      0.99      0.98      1330
#          6.0       0.90      0.92      0.91      1330
#          7.0       1.00      1.00      1.00      1330
#          8.0       0.99      0.98      0.98      1330
#          9.0       0.91      0.95      0.93      1330
#         10.0       0.89      0.91      0.90      1330
#         11.0       1.00      1.00      1.00      1330
#
#     accuracy                           0.96     14628
#    macro avg       0.96      0.96      0.96     14628
# weighted avg       0.96      0.96      0.96     14628

# %%
accuracy = accuracy_score(y_test, yhat)
precision = precision_score(y_test, yhat, average = 'macro')
recall = recall_score(y_test, yhat, average = 'macro')
f1 = f1_score(y_test, yhat, average = 'macro')
#roc_auc = roc_auc_score(y_test, yhat, multi_class = 'ovr')

scores = {'accuracy' : accuracy,
          'precision' : precision,
          'recall' : recall,
          'f1' : f1
          #'roc_auc' : roc_auc
         }

scores
# Out:
# {'accuracy': 0.9586409625375991,
#  'precision': 0.9591144380425752,
#  'recall': 0.9586422962804096,
#  'f1': 0.9587275510517638}

# %%
new_accuracy = accuracy_score(y_test, new_yhat)
new_precision = precision_score(y_test, new_yhat, average = 'macro')
new_recall = recall_score(y_test, new_yhat, average = 'macro')
new_f1 = f1_score(y_test, new_yhat, average = 'macro')
#new_roc_auc = roc_auc_score(y_test, new_ada_yhat, multi_class = 'ovr')

new_scores = {'accuracy' : new_accuracy,
          'precision' : new_precision,
          'recall' : new_recall,
          'f1' : new_f1
          #'roc_auc' : roc_auc
         }

new_scores
# Out:
# {'accuracy': 0.8287530762920426,
#  'precision': 0.8284617545439269,
#  'recall': 0.8287606457144299,
#  'f1': 0.8180080702153454}
