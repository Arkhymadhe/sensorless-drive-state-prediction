# %%
# Importing required libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

# %%
# Loading in the data
DIR = os.getcwd().replace('notebooks', 'data')
data = np.loadtxt(DIR + '\\' + 'Sensorless_drive_diagnosis.txt')

# %%
data.shape
# Out:
# (58509, 49)

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#              0             1         2         3             4         5   \
# 0 -3.014600e-07  8.260300e-06 -0.000012 -0.000002 -1.438600e-06 -0.000021
# 1  2.913200e-06 -5.247700e-06  0.000003 -0.000006  2.778900e-06 -0.000004
# 2 -2.951700e-06 -3.184000e-06 -0.000016 -0.000001 -1.575300e-06  0.000017
# 3 -1.322600e-06  8.820100e-06 -0.000016 -0.000005 -7.282900e-07  0.000004
# 4 -6.836600e-08  5.666300e-07 -0.000026 -0.000006 -7.940600e-07  0.000013
#
#          6         7         8         9   ...       39      40      41  \
# 0  0.031718  0.031710  0.031721 -0.032963  ... -0.63308  2.9646  8.1198
# 1  0.030804  0.030810  0.030806 -0.033520  ... -0.59314  7.6252  6.1690
# 2  0.032877  0.032880  0.032896 -0.029834  ... -0.63252  2.7784  5.3017
# 3  0.029410  0.029401  0.029417 -0.030156  ... -0.62289  6.5534  6.2606
# 4  0.030119  0.030119  0.030145 -0.031393  ... -0.63010  4.5155  9.5231
#
#        42      43      44      45      46      47   48
# 0 -1.4961 -1.4961 -1.4961 -1.4996 -1.4996 -1.4996  1.0
# 1 -1.4967 -1.4967 -1.4967 -1.5005 -1.5005 -1.5005  1.0
# 2 -1.4983 -1.4983 -1.4982 -1.4985 -1.4985 -1.4985  1.0
# 3 -1.4963 -1.4963 -1.4963 -1.4975 -1.4975 -1.4976  1.0
# 4 -1.4958 -1.4958 -1.4958 -1.4959 -1.4959 -1.4959  1.0
#
# [5 rows x 49 columns]

# %%
desc = {'name' : np.array(data.index) + 1,
        'null' : data.isnull().sum(),
        'null%' : data.isnull().sum()/data.shape[0],
        'unique' : data.nunique(),
        'unique%' : data.nunique()/data.shape[0],
        'dtypes' : data.dtypes}

desc = pd.DataFrame(desc)

# %%
desc
# Out:
#     null  null%  unique   unique%   dtypes
# 0      0    0.0   50500  0.863115  float64
# 1      0    0.0   52709  0.900870  float64
# 2      0    0.0   52501  0.897315  float64
# 3      0    0.0   51298  0.876754  float64
# 4      0    0.0   52523  0.897691  float64
# 5      0    0.0   52423  0.895982  float64
# 6      0    0.0   43677  0.746501  float64
# 7      0    0.0   43582  0.744877  float64
# 8      0    0.0   43665  0.746295  float64
# 9      0    0.0   44196  0.755371  float64
# 10     0    0.0   44313  0.757371  float64
# 11     0    0.0   44422  0.759234  float64
# 12     0    0.0   16551  0.282880  float64
# 13     0    0.0   29770  0.508811  float64
# 14     0    0.0   42721  0.730161  float64
# 15     0    0.0   17611  0.300996  float64
# 16     0    0.0   29740  0.508298  float64
# 17     0    0.0   42657  0.729067  float64
# 18     0    0.0   12812  0.218975  float64
# 19     0    0.0   12798  0.218736  float64
# 20     0    0.0   12738  0.217710  float64
# 21     0    0.0   12754  0.217984  float64
# 22     0    0.0   12738  0.217710  float64
# 23     0    0.0   12691  0.216907  float64
# 24     0    0.0   48937  0.836401  float64
# 25     0    0.0   51871  0.886547  float64
# 26     0    0.0   51524  0.880617  float64
# 27     0    0.0   49711  0.849630  float64
# 28     0    0.0   51754  0.884548  float64
# 29     0    0.0   51602  0.881950  float64
# 30     0    0.0   50113  0.856501  float64
# 31     0    0.0   50085  0.856022  float64
# 32     0    0.0   50037  0.855202  float64
# 33     0    0.0   50709  0.866687  float64
# 34     0    0.0   50910  0.870123  float64
# 35     0    0.0   50888  0.869747  float64
# 36     0    0.0   29145  0.498128  float64
# 37     0    0.0   46556  0.795707  float64
# 38     0    0.0   42536  0.726999  float64
# 39     0    0.0   29454  0.503410  float64
# 40     0    0.0   46788  0.799672  float64
# 41     0    0.0   42377  0.724282  float64
# 42     0    0.0     265  0.004529  float64
# 43     0    0.0     267  0.004563  float64
# 44     0    0.0     264  0.004512  float64
# 45     0    0.0     242  0.004136  float64
# 46     0    0.0     243  0.004153  float64
# 47     0    0.0     243  0.004153  float64
# 48     0    0.0      11  0.000188  float64

# %%
data.describe()
# Out:
#                  0             1             2             3             4   \
# count  58509.000000  5.850900e+04  5.850900e+04  58509.000000  5.850900e+04
# mean      -0.000003  1.439648e-06  1.412013e-06     -0.000001  1.351239e-06
# std        0.000072  5.555429e-05  2.353009e-04      0.000063  5.660943e-05
# min       -0.013721 -5.414400e-03 -1.358000e-02     -0.012787 -8.355900e-03
# 25%       -0.000007 -1.444400e-05 -7.239600e-05     -0.000005 -1.475300e-05
# 50%       -0.000003  8.804600e-07  5.137700e-07     -0.000001  7.540200e-07
# 75%        0.000002  1.877700e-05  7.520000e-05      0.000004  1.906200e-05
# max        0.005784  4.525300e-03  5.237700e-03      0.001453  8.245100e-04
#
#                  5             6             7             8             9   \
# count  5.850900e+04  58509.000000  58509.000000  58509.000000  58509.000000
# mean  -2.654483e-07      0.001915      0.001913      0.001912     -0.011897
# std    2.261907e-04      0.036468      0.036465      0.036470      0.066482
# min   -9.741300e-03     -0.139890     -0.135940     -0.130860     -0.218640
# 25%   -7.379100e-05     -0.019927     -0.019951     -0.019925     -0.032144
# 50%   -1.659300e-07      0.013226      0.013230      0.013247     -0.015566
# 75%    7.138600e-05      0.024770      0.024776      0.024777      0.020614
# max    2.753600e-03      0.069125      0.069130      0.069131      0.352580
#
#        ...            39            40            41            42  \
# count  ...  58509.000000  58509.000000  58509.000000  58509.000000
# mean   ...     -0.397757      7.293781      8.273772     -1.500887
# std    ...     25.018728     12.451781      6.565952      0.003657
# min    ...     -0.902350     -0.596830      0.320660     -1.525500
# 25%    ...     -0.715470      1.450300      4.436300     -1.503300
# 50%    ...     -0.661710      3.301300      6.479100     -1.500300
# 75%    ...     -0.573980      8.288500      9.857500     -1.498200
# max    ...   3670.800000    889.930000    153.150000     -1.457600
#
#                  43            44            45            46            47  \
# count  58509.000000  58509.000000  58509.000000  58509.000000  58509.000000
# mean      -1.500912     -1.500805     -1.497771     -1.497794     -1.497686
# std        0.003668      0.003632      0.003163      0.003163      0.003175
# min       -1.526200     -1.523700     -1.521400     -1.523200     -1.521300
# 25%       -1.503400     -1.503200     -1.499600     -1.499600     -1.499500
# 50%       -1.500300     -1.500300     -1.498100     -1.498100     -1.498000
# 75%       -1.498200     -1.498200     -1.496200     -1.496300     -1.496200
# max       -1.456100     -1.455500     -1.337200     -1.337200     -1.337100
#
#                  48
# count  58509.000000
# mean       6.000000
# std        3.162305
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%        9.000000
# max       11.000000
#
# [8 rows x 49 columns]

# %%
plt.figure(figsize = (10, 8))
sns.countplot(x = 48, data = data)
plt.show()

# %%
# Univariate visualization
def univariate_plot(data):
    
    ''' Plot the data univariately. '''
    
    for col in data.columns:
        plt.figure(figsize = (10, 8))
        sns.distplot(data[col])
        plt.show()

# %%
data.groupby(by = 48)[48].count()
# Out:
# 48
# 1.0     5319
# 2.0     5319
# 3.0     5319
# 4.0     5319
# 5.0     5319
# 6.0     5319
# 7.0     5319
# 8.0     5319
# 9.0     5319
# 10.0    5319
# 11.0    5319
# Name: 48, dtype: int64

# %% [markdown]
# <h4> As can be seen from the analysis made above, the data is balanced with respect to class. This means that the accuracy metric can be trusted.<h4>

# %%
univariate_plot(data)

# %%
hue = data[48]

# %%
sns.pairplot(data = data, hue = 48)

# %% [markdown]
# <h4> We will be fitting the data to an instance of the ExtraTree classifier.

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
tree = ExtraTreesClassifier(max_depth = 3, random_state = 42)

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.iloc[:, : -1]
y = data.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, stratify = y)

# %%
tree.fit(X_train, y_train)
yhat = tree.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
print(classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.73      0.72      0.72      1330
#          2.0       0.88      0.77      0.82      1329
#          3.0       0.74      0.92      0.82      1330
#          4.0       0.94      0.79      0.86      1330
#          5.0       0.82      0.56      0.67      1329
#          6.0       0.73      0.58      0.64      1330
#          7.0       0.87      1.00      0.93      1330
#          8.0       0.75      0.89      0.81      1330
#          9.0       0.65      0.73      0.69      1330
#         10.0       0.80      0.89      0.84      1330
#         11.0       1.00      1.00      1.00      1330
#
#     accuracy                           0.80     14628
#    macro avg       0.81      0.80      0.80     14628
# weighted avg       0.81      0.80      0.80     14628

# %% [markdown]
# <h4>From the results obtained above, it is seen that the model performs quite well, even without any serious hyperparametric tuning. Let us attempt to improve it through feature selection.

# %%
feature_ranks = tree.feature_importances_

# %%
feature_ranks
# Out:
# array([3.91046010e-04, 1.47941478e-04, 1.19397656e-04, 0.00000000e+00,
#        2.03845033e-03, 2.12362972e-05, 1.31058817e-01, 1.42196738e-01,
#        1.36060888e-01, 1.88192565e-01, 1.44725216e-01, 1.05817812e-01,
#        2.16567178e-03, 6.72454637e-04, 7.11393879e-06, 2.03372960e-03,
#        2.76292269e-03, 1.48397706e-04, 2.23669028e-02, 1.22607620e-02,
#        4.05150810e-03, 1.82062418e-02, 8.47369118e-03, 1.17799626e-02,
#        2.13741258e-06, 1.43661164e-04, 2.01117955e-05, 1.31467580e-05,
#        2.91395980e-04, 3.27576921e-06, 6.77510448e-03, 8.53398851e-03,
#        1.79645900e-02, 9.44076401e-03, 6.48554597e-03, 8.76587950e-03,
#        2.27983460e-05, 3.40399871e-05, 1.32262288e-05, 1.96540242e-05,
#        7.32442764e-06, 3.27434754e-05, 1.97764955e-04, 2.81248410e-03,
#        2.25334840e-03, 5.67137448e-05, 1.22905706e-04, 2.87930024e-04])

# %%
feature_ranks.shape
# Out:
# (48,)

# %%
plt.figure(figsize = (20, 8))
sns.barplot(x = data.iloc[:, : -1].columns, y = 10**6*feature_ranks, color = 'blue')

# %%
importances = pd.DataFrame({'Importance' : 1000*feature_ranks,
                            'Feature' : ['Feature {}'.format(i + 1) for i in data.iloc[:, : -1].columns]
                           })

# %%
importances
# Out:
#     Importance     Feature
# 0     0.391046   Feature 1
# 1     0.147941   Feature 2
# 2     0.119398   Feature 3
# 3     0.000000   Feature 4
# 4     2.038450   Feature 5
# 5     0.021236   Feature 6
# 6   131.058817   Feature 7
# 7   142.196738   Feature 8
# 8   136.060888   Feature 9
# 9   188.192565  Feature 10
# 10  144.725216  Feature 11
# 11  105.817812  Feature 12
# 12    2.165672  Feature 13
# 13    0.672455  Feature 14
# 14    0.007114  Feature 15
# 15    2.033730  Feature 16
# 16    2.762923  Feature 17
# 17    0.148398  Feature 18
# 18   22.366903  Feature 19
# 19   12.260762  Feature 20
# 20    4.051508  Feature 21
# 21   18.206242  Feature 22
# 22    8.473691  Feature 23
# 23   11.779963  Feature 24
# 24    0.002137  Feature 25
# 25    0.143661  Feature 26
# 26    0.020112  Feature 27
# 27    0.013147  Feature 28
# 28    0.291396  Feature 29
# 29    0.003276  Feature 30
# 30    6.775104  Feature 31
# 31    8.533989  Feature 32
# 32   17.964590  Feature 33
# 33    9.440764  Feature 34
# 34    6.485546  Feature 35
# 35    8.765879  Feature 36
# 36    0.022798  Feature 37
# 37    0.034040  Feature 38
# 38    0.013226  Feature 39
# 39    0.019654  Feature 40
# 40    0.007324  Feature 41
# 41    0.032743  Feature 42
# 42    0.197765  Feature 43
# 43    2.812484  Feature 44
# 44    2.253348  Feature 45
# 45    0.056714  Feature 46
# 46    0.122906  Feature 47
# 47    0.287930  Feature 48

# %%
# Selecting the indexes of features which have importances greater than 1
i = 0
indexes = []

while i < 48:
    if list(1000*feature_ranks)[i] > 10:
        indexes.append(i)
    i += 1

# %%
indexes
# Out:
# [4,
#  6,
#  7,
#  8,
#  9,
#  10,
#  11,
#  12,
#  15,
#  16,
#  18,
#  19,
#  20,
#  21,
#  22,
#  23,
#  30,
#  31,
#  32,
#  33,
#  34,
#  35,
#  43,
#  44]

# %%
### Index out selected features
X_train_new = X_train.iloc[:, indexes]
X_test_new = X_test.iloc[:, indexes]

# %%
new_tree = ExtraTreesClassifier(max_depth = 3, random_state = 42)

# %%
### Train model and test preformance
new_tree.fit(X_train_new, y_train)
new_yhat = new_tree.predict(X_test_new)

# %%
print(classification_report(y_test, new_yhat))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.72      0.84      0.77      1330
#          2.0       0.86      0.86      0.86      1329
#          3.0       0.82      0.96      0.88      1330
#          4.0       0.80      0.79      0.80      1330
#          5.0       0.90      0.59      0.71      1329
#          6.0       0.62      0.50      0.55      1330
#          7.0       0.88      1.00      0.94      1330
#          8.0       0.84      0.91      0.88      1330
#          9.0       0.73      0.74      0.73      1330
#         10.0       0.86      0.86      0.86      1330
#         11.0       1.00      1.00      1.00      1330
#
#     accuracy                           0.82     14628
#    macro avg       0.82      0.82      0.82     14628
# weighted avg       0.82      0.82      0.82     14628

# %% [markdown]
# <h4> We seem to have cut down on the not-so-important features. The ExtraTreesClassifier has an even more competent degree of accuracy. Perhaps this can be improved on by utilizing it as the basis for a boosting machine.<h4>
#
# The selected boosting machine is an AdaBoostClassifier.

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
Ada_model = AdaBoostClassifier(base_estimator = ExtraTreesClassifier(max_depth = 3, random_state = 42), random_state = 42)

# %%
Ada_model.fit(X_train_new, y_train)
yhat = Ada_model.predict(X_test_new)
print(classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.96      0.98      1330
#          2.0       0.88      0.83      0.85      1329
#          3.0       1.00      1.00      1.00      1330
#          4.0       0.99      0.99      0.99      1330
#          5.0       0.97      0.99      0.98      1329
#          6.0       0.91      0.90      0.91      1330
#          7.0       1.00      0.99      0.99      1330
#          8.0       0.99      0.98      0.98      1330
#          9.0       0.90      0.95      0.92      1330
#         10.0       0.85      0.88      0.86      1330
#         11.0       1.00      1.00      1.00      1330
#
#     accuracy                           0.95     14628
#    macro avg       0.95      0.95      0.95     14628
# weighted avg       0.95      0.95      0.95     14628

# %%
accuracy = accuracy_score(y_test, yhat)
precision = precision_score(y_test, yhat, average = 'macro')
recall = recall_score(y_test, yhat, average = 'macro')
f1 = f1_score(y_test, yhat, average = 'macro')
#roc_auc = roc_auc_score(y_test, yhat, multi_class = 'ovr')

scores = {'accuracy' : accuracy,
          'precision' : precision,
          'recall' : recall,
          'f1' : f1
          #'roc_auc' : roc_auc
         }

scores
# Out:
# {'accuracy': 0.9520098441345365,
#  'precision': 0.9525176257729367,
#  'recall': 0.9520041639086428,
#  'f1': 0.9520359177987608}

# %%
new_accuracy = accuracy_score(y_test, new_ada_yhat)
new_precision = precision_score(y_test, new_ada_yhat, average = 'macro')
new_recall = recall_score(y_test, new_ada_yhat, average = 'macro')
new_f1 = f1_score(y_test, new_ada_yhat, average = 'macro')
#new_roc_auc = roc_auc_score(y_test, new_ada_yhat, multi_class = 'ovr')

new_scores = {'accuracy' : new_accuracy,
          'precision' : new_precision,
          'recall' : new_recall,
          'f1' : new_f1
          #'roc_auc' : roc_auc
         }

new_scores
# Out:
# {'accuracy': 0.9520098441345365,
#  'precision': 0.9525176257729367,
#  'recall': 0.9520041639086428,
#  'f1': 0.9520359177987608}
